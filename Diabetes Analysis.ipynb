# %% [markdown]
# # Import the necessary libraries

# %%
import pandas as pd #used for data preparation
import numpy as np  # linear algebra operation
import matplotlib.pyplot as plt # for visualization
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
df =pd.read_csv('diabetes.csv')

# %% [markdown]
# # Exploring the dataset

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns #checking for columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # The dataset has the following features (columns):
# ### Pregnancies: Number of pregnancy
# ### Glucose: Plasma glucose concentration
# ### Bloodprssure: Diastolic bloodpressure
# ### SkinThickness: Triceps skin fold thickness
# ### Insulin: 2-Hour serum insulin
# ### BMI: Body Mass Index (weight in kg/ height in meter square)
# ### DiabetesPedigreeFunction: This indicates the likelihood of diabetes based on family history
# ### Age:age(in years)
# ### Outcome: Whether a patient is diagnose with diabetes or not(0 for No, 1 for yes)

# %% [markdown]
# # Checking for Null Values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Filling Missing Values

# %% [markdown]
# ## We will replace the 0-values of the following columns with their mediann values
# - Glucose
# - BloodPressure
# - skinThickness
# - Insulin
# - BMI

# %%
# filling the missing values with the median value of the particular columns
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].median())
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].median())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].median())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].median())
df['BMI']=df['BMI'].replace(0,df['BMI'].median())

# %% [markdown]
# # Data visualization

# %%
## Visualizing the data using univariate variable
## Univariate analysis

# %%
fig1,ax1 = plt.subplots(1, 2, figsize=(20,7))
fig2,ax2 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="Pregnancies", kde=True, ax=ax1[0],color='blue')
sns.boxplot(data=df, x="Pregnancies", ax=ax1[1],color = 'magenta')

sns.violinplot(data=df, x="Pregnancies", ax=ax2,color='orange')

plt.show()

# %%
print("Median of Pregnancies: ", df["Pregnancies"].median())
print("Maximum of Pregnancies: ", df["Pregnancies"].max())
# Out:
# Median of Pregnancies:  3.0
# Maximum of Pregnancies:  17

# %%
df["Pregnancies"].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64

# %% [markdown]
# # From the above analysis, we observe that:
# ##### . Most patients had 0, 1 or 2 pregnancies
# ##### . Median value of pregenancies is 3
# ##### . Also, patients has upto 17 pregnancies
# ##### . Outliers are also observe on the boxplot

# %% [markdown]
# # Analysis of outcome(Target Variable)
# A Count plot and a Pie chart will be two useful plots to analyse the Outcome

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# First plot: Countplot
sns.countplot(data=df, x="Outcome", ax=ax[0])

# Second plot: Pie chart
df["Outcome"].value_counts().plot.pie(
    explode=[0.1, 0],
    autopct="%1.1f%%",
    labels=["No", "Yes"],
    shadow=True,
    ax=ax[1]
)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## From the above, we observe that:
# #### 65.1% patients in the dataset do not have diabetes
# #### 34.9% patients in the dataset has diabetes

# %% [markdown]
# # Analysis of the Glucose
# Glucose is a quantitative feature.Histograms, Boxplots and violin plots are usefulto know the distribution of the data

# %%
fig3, ax3 =plt.subplots(1,2,figsize=(20,7))
fig4, ax4 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="Glucose", kde=True, ax=ax3[0], color='blue')
sns.boxplot(data=df, x="Glucose", ax=ax3[1], color='magenta')


sns.violinplot(data=df, x="Glucose", ax=ax4, color='orange')

plt.show()

# %%
print("Median of Glucose:",df["Glucose"].median())
print("Maximum of Glucose:",df["Glucose"].max())
print("Mean of Glucose:",df["Glucose"].mean())
# Out:
# Median of Glucose: 117.0
# Maximum of Glucose: 199
# Mean of Glucose: 121.65625

# %%
print("Rows with Glucose value of 0:", df[df["Glucose"]==0].shape[0])
# Out:
# Rows with Glucose value of 0: 0

# %% [markdown]
# # Observation
# We observe that:
# #### . Median(117.0) and mean(121.6) of Glucose lie very close to each other i.e the distribution is more  or less symmtric and uniform
#
# #### . There are no rows with Glucose value as 0

# %% [markdown]
# # Analysis of BloodPressure
# Glucose is a quantitative feature.Histograms, Boxplots and violin plots are useful to know the distribution of the data

# %%
fig5, ax5 =plt.subplots(1,2,figsize=(20,7))
fig6, ax6 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="BloodPressure", kde=True, ax=ax5[0], color='blue')
sns.boxplot(data=df, x="BloodPressure", ax=ax5[1], color='magenta')


sns.violinplot(data=df, x="BloodPressure", ax=ax6, color='orange')

plt.show()

# %%
print("Median of BloodPressure:",df["BloodPressure"].median())
print("Maximum of BloodPressure:",df["BloodPressure"].max())
print("Mean of BloodPressure:",df["BloodPressure"].mean())
# Out:
# Median of BloodPressure: 72.0
# Maximum of BloodPressure: 122
# Mean of BloodPressure: 72.38671875

# %%
print("Rows with BloodPressure value of 0:", df[df["BloodPressure"]==0].shape[0])
# Out:
# Rows with BloodPressure value of 0: 0

# %% [markdown]
# # Observation
# We observe that:
#
# . Median(72.0) and mean(69.1) of BloodPressure lie very close to each other i.e the distribution is more or less symmtric and uniform
# . As observed from the boxplot and violin plot, some outlier lies on 0-value
# . There is no rows with BlooDPressure value as 0

# %% [markdown]
# # Analysis of the Insulin
# Insulin is a quantitative feature.Histograms, Boxplots and violin plots are useful to know the distribution of the data

# %%
fig7, ax7 =plt.subplots(1,2,figsize=(20,7))
fig8, ax8 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="Insulin", kde=True, ax=ax7[0], color='blue')
sns.boxplot(data=df, x="Insulin", ax=ax7[1], color='magenta')


sns.violinplot(data=df, x="Insulin", ax=ax8, color='orange')

plt.show()

# %%
print("Median of Insulin:",df["Insulin"].median())
print("Maximum of Insulin:",df["Insulin"].max())
print("Mean of Insulin:",df["Insulin"].mean())
# Out:
# Median of Insulin: 31.25
# Maximum of Insulin: 846.0
# Mean of Insulin: 94.65234375

# %%
print("Rows with Insulin value of 0:", df[df["Insulin"]==0].shape[0])
# Out:
# Rows with Insulin value of 0: 0

# %% [markdown]
# # Observation
# We observe tthat:
# The plot for insulin are highly skewed. Also, the 0-value logical error is the most  for this feature, no
# instances have value of insulin as 0

# %% [markdown]
# # Analysis of BloodPressure
# Glucose is a quantitative feature.Histograms, Boxplots and violin plots are useful to know the distribution of the data

# %%
fig9, ax9 =plt.subplots(1,2,figsize=(20,7))
fig10, ax10 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="BMI", kde=True, ax=ax9[0], color='blue')
sns.boxplot(data=df, x="BMI", ax=ax9[1], color='magenta')


sns.violinplot(data=df, x="BMI", ax=ax10, color='orange')

plt.show()

# %%
print("Median of BMI:",df["BMI"].median())
print("Maximum of BMI:",df["BMI"].max())
print("Mean of BMI:",df["BMI"].mean())
# Out:
# Median of BMI: 32.0
# Maximum of BMI: 67.1
# Mean of BMI: 32.45091145833333

# %%
print("Rows with BMI value of 0:", df[df["BMI"]==0].shape[0])
# Out:
# Rows with BMI value of 0: 0

# %% [markdown]
# # Observation
# We observe that:
# #### . Median(32.0) and Mean (31.9) of BMI are very close to each other. Thus the distribution is more or less symmetric and uniform
# #### . Maximum BMI is 67.1
# #### . Zero rows with BMI value as 0

# %% [markdown]
# # Analysis of DiabetesPedigreeFunction
# Glucose is a quantitative feature.Histograms, Boxplots and violin plots are usefulto know the distribution of the data

# %%
fig11, ax11 =plt.subplots(1,2,figsize=(20,7))
fig12, ax12 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="DiabetesPedigreeFunction", kde=True, ax=ax11[0], color='blue')
sns.boxplot(data=df, x="DiabetesPedigreeFunction", ax=ax11[1], color='magenta')


sns.violinplot(data=df, x="DiabetesPedigreeFunction", ax=ax12, color='orange')

plt.show()

# %%
print("Median of DiabetesPedigreeFunction:",df["DiabetesPedigreeFunction"].median())
print("Maximum of DiabetesPedigreeFunction:",df["DiabetesPedigreeFunction"].max())
print("Mean of DiabetesPedigreeFunction:",df["DiabetesPedigreeFunction"].mean())
# Out:
# Median of DiabetesPedigreeFunction: 0.3725
# Maximum of DiabetesPedigreeFunction: 2.42
# Mean of DiabetesPedigreeFunction: 0.47187630208333325

# %%
print("Rows with  DiabetesPedigreeFunction value of 0:", df[df["DiabetesPedigreeFunction"]==0].shape[0])
# Out:
# Rows with  DiabetesPedigreeFunction value of 0: 0

# %% [markdown]
# # Observation
# We observe that:
# #### . The histogram is highly skewed on the left side
# #### . There are many outliers in the Box plot
# #### . violin plot distribution is dense in the interval 0.0 - 1.0

# %% [markdown]
#  # Analysis of Age
# Glucose is a quantitative feature.Histograms, Boxplots and violin plots are usefulto know the distribution of the data

# %%
fig13, ax13 =plt.subplots(1,2,figsize=(20,7))
fig14, ax14 = plt.subplots(figsize=(20,7))

sns.histplot(data=df, x="Age", kde=True, ax=ax13[0], color='blue')
sns.boxplot(data=df, x="Age", ax=ax13[1], color='magenta')


sns.violinplot(data=df, x="Age", ax=ax14, color='orange')

plt.show()

# %%
print("Median of Age:",df["Age"].median())
print("Maximum of Age:",df["Age"].max())
print("Mean of Age:",df["Age"].mean())
# Out:
# Median of Age: 29.0
# Maximum of Age: 81
# Mean of Age: 33.240885416666664

# %%
print("Rows with Age value of 0:", df[df["Age"]==0].shape[0])
# Out:
# Rows with Age value of 0: 0

# %% [markdown]
# # Observation
# We observe that:
# #### . The age is skewed to the left
# #### . Also there are outliers in the Boxplot

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # Analysis of Glucose and outcome
# Since Glocose is a continous feature, we plota histogram with its hye based on Outcome

# %%
fig15, ax15 = plt.subplots(figsize=(20,7))

sns.histplot(data=df,x="Glucose", hue="Outcome", shrink =0.8, multiple="fill", kde= True,ax=ax15)

plt.show()

# %% [markdown]
# ### From the above, we observe a positive linear correlation
#
# ##### As the value of Glucose increases, the count of patients having diabetes increases i.e. value of Outcome as 1, increases
# #### Also, after ther Glucose value of 125, there is a steady increase in the number of patients having Outcome of 1
# #### Note, when Glucose value is 0, it means the measurement is missing.we need to fill that value with the mean or median and then it will make sense
# so, there is a significant amount of positive  linear correlation

# %% [markdown]
# # Analysis of BloodPressure and Outcome
# ### BloodPressure is continous and outcome is binary feature, we are plotting a histogram of BloodPressure with its hue based on Outcome

# %%
fig16,ax16=plt.subplots(figsize=(20,7))

sns.histplot(data=df,x="BloodPressure",hue="Outcome", shrink=0.8, multiple="dodge", kde=True, ax=ax16)
plt.show()

# %% [markdown]
# # observation
# ##### we observe that,Outcome and BloodPressure do not have positive or negative linear correlation. THe value of Outciome do not increases linearly as value of BloodPressure increases
# ##### However, for BlioodPressure values greate than 85, count of patients with outcome as 1 is ,more

# %% [markdown]
# # Analysis of BMI and Outcome

# %%
fig17,ax17=plt.subplots(figsize=(20,7))

sns.histplot(data=df,x="BMI",hue="Outcome", shrink=0.8, multiple="fill", kde=True, ax=ax17)
plt.show()

# %% [markdown]
# From the above , a positive linear correlation is observe in BMI

# %% [markdown]
# # Analysis of Age and Outcome

# %%
fig18,ax18=plt.subplots(figsize=(20,7))

sns.histplot(data=df,x="Age",hue="Outcome", shrink=0.8, multiple="dodge", kde=True, ax=ax18)
plt.show()

# %% [markdown]
# For age greater than 35 years , the chances of patients ahving diabetes increases as seen in the plot ie. the number of patients having diabetes is more than the number of poeple not having diabetees. But this does not hold true for age like 60+.

# %%
# Analysis of Pregnancy and Outcome
fig19, ax19=plt.subplots(figsize=(20,7))
sns.histplot(data=df, x="Pregnancies",hue="Outcome", shrink =0.8, multiple="fill",kde=True,ax=ax19)
plt.show()

# %% [markdown]
# There is a positive correlation between pregnancies and Outcome

# %% [markdown]
# # Analyzing correlations

# %%
# ploting a heatmap of the correlation matrix of different features
#The 2D correlation matrix
corr_matrix =df.corr()

# %%
# plotting the heatmap of corr

fig20, ax20=plt.subplots(figsize=(20,7))
dataplot =sns.heatmap(data=corr_matrix, annot=True, ax=ax20)
plt.show()

# %%
corr_matrix["Outcome"].sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.492782
# BMI                         0.312249
# Age                         0.238356
# Pregnancies                 0.221898
# SkinThickness               0.189065
# DiabetesPedigreeFunction    0.173844
# BloodPressure               0.165723
# Insulin                     0.148457
# Name: Outcome, dtype: float64

# %% [markdown]
# # We observe that:
# #### . Glucose has maximum positive linear correlation with Outcome
# #### . BloodPressure has the lowest positive linear correlation with Outcome
# #### . No feature has a negative linear correlation with Outcome

# %% [markdown]
# # Filling missing Values

# %% [markdown]
# # We will replace the 0-values of the following columns with their mean values
# #### Glucose
# #### BloodPressure
# #### skinThickness
# #### Insulin
# #### BMI

# %%
# copying the original datset inot a new pandas dataframe
df_cp=df.copy()

# %%
# filling the missing values with the median value of the particular columns
df_cp['Glucose']=df['Glucose'].replace(0,df['Glucose'].median())
df_cp['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].median())
df_cp['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].median())
df_cp['Insulin']=df['Insulin'].replace(0,df['Insulin'].median())
df_cp['BMI']=df['BMI'].replace(0,df['BMI'].median())

# %%
df_cp.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  121.656250   30.438286  44.000  99.75000
# BloodPressure             768.0   72.386719   12.096642  24.000  64.00000
# SkinThickness             768.0   27.334635    9.229014   7.000  23.00000
# Insulin                   768.0   94.652344  105.547598  14.000  30.50000
# BMI                       768.0   32.450911    6.875366  18.200  27.50000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# #### We replace all missing values with the median(of that column) in the Training set and used the learned median to replace  the missing values in the Testing set

# %%
df_cp.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
fig1,ax1 = plt.subplots(1, 2, figsize=(20,7))
fig2,ax2 = plt.subplots(figsize=(20,7))

sns.histplot(data=df_cp, x="Pregnancies", kde=True, ax=ax1[0],color='blue')
sns.boxplot(data=df_cp, x="Pregnancies", ax=ax1[1],color = 'magenta')

sns.violinplot(data=df_cp, x="Pregnancies", ax=ax2,color='orange')

plt.show()

# %%
print("Median of Pregnancies: ", df["Pregnancies"].median())
print("Maximum of Pregnancies: ", df["Pregnancies"].max())
# Out:
# Median of Pregnancies:  3.0
# Maximum of Pregnancies:  17

# %%
df_cp["Pregnancies"].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64
